# %%
def print_board(board):
    """Prints the Tic Tac Toe board."""
    for row in board:
        print(" | ".join(row))
        print("-" * 9)


def check_winner(board):
    """Check if there is a winner."""
    # Check rows
    for row in board:
        if row[0] == row[1] == row[2] != ' ':
            return True, row[0]
    # Check columns
    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] != ' ':
            return True, board[0][col]
    # Check diagonals
    if board[0][0] == board[1][1] == board[2][2] != ' ':
        return True, board[0][0]
    if board[0][2] == board[1][1] == board[2][0] != ' ':
        return True, board[0][2]
    return False, None


def is_board_full(board):
    """Check if the board is full."""
    for row in board:
        for cell in row:
            if cell == ' ':
                return False
    return True


def main():
    board = [[' ' for _ in range(3)] for _ in range(3)]
    current_player = 'X'

    while True:
        print_board(board)

        # Get user input
        row = int(input(f"Player {current_player}, choose row (0, 1, 2): "))
        col = int(input(f"Player {current_player}, choose column (0, 1, 2): "))

        # Check if the chosen cell is empty
        if board[row][col] != ' ':
            print("This cell is already occupied. Try again.")
            continue

        # Place the player's mark on the board
        board[row][col] = current_player

        # Check if the game is over
        winner_found, winner = check_winner(board)
        if winner_found:
            print_board(board)
            print(f"Player {winner} wins!")
            break
        elif is_board_full(board):
            print_board(board)
            print("It's a tie!")
            break

        # Switch player
        current_player = 'O' if current_player == 'X' else 'X'


if __name__ == "__main__":
    main()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player X, choose row (0, 1, 2): 0 0 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 70
#      66         current_player = 'O' if current_player == 'X' else 'X'
#      69 if __name__ == "__main__":
# ---> 70     main()
#
# Cell In[1], line 43, in main()
#      40 print_board(board)
#      42 # Get user input
# ---> 43 row = int(input(f"Player {current_player}, choose row (0, 1, 2): "))
#      44 col = int(input(f"Player {current_player}, choose column (0, 1, 2): "))
#      46 # Check if the chosen cell is empty
#
# ValueError: invalid literal for int() with base 10: '0 0 0'

# %%
def print_board(board):
    """Prints the Tic Tac Toe board."""
    for row in board:
        print(" | ".join(row))
        print("-" * 9)


def check_winner(board):
    """Check if there is a winner."""
    # Check rows
    for row in board:
        if row[0] == row[1] == row[2] != ' ':
            return True, row[0]
    # Check columns
    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] != ' ':
            return True, board[0][col]
    # Check diagonals
    if board[0][0] == board[1][1] == board[2][2] != ' ':
        return True, board[0][0]
    if board[0][2] == board[1][1] == board[2][0] != ' ':
        return True, board[0][2]
    return False, None


def is_board_full(board):
    """Check if the board is full."""
    for row in board:
        for cell in row:
            if cell == ' ':
                return False
    return True


def main():
    board = [[' ' for _ in range(3)] for _ in range(3)]
    current_player = 'X'

    while True:
        print_board(board)

        # Get user input
        while True:
            try:
                row = int(input(f"Player {current_player}, choose row (0, 1, 2): "))
                col = int(input(f"Player {current_player}, choose column (0, 1, 2): "))

                # Check if row and column are within range
                if row not in range(3) or col not in range(3):
                    raise ValueError("Row and column must be between 0 and 2.")

                # Check if the chosen cell is empty
                if board[row][col] != ' ':
                    print("This cell is already occupied. Try again.")
                    continue

                break  # Input is valid, break out of the loop
            except ValueError:
                print("Invalid input. Please enter integers between 0 and 2.")

        # Place the player's mark on the board
        board[row][col] = current_player

        # Check if the game is over
        winner_found, winner = check_winner(board)
        if winner_found:
            print_board(board)
            print(f"Player {winner} wins!")
            break
        elif is_board_full(board):
            print_board(board)
            print("It's a tie!")
            break

        # Switch player
        current_player = 'O' if current_player == 'X' else 'X'


if __name__ == "__main__":
    main()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player X, choose row (0, 1, 2): 1 2 3
# Invalid input. Please enter integers between 0 and 2.
# Player X, choose row (0, 1, 2): 0
# Player X, choose column (0, 1, 2): 0
# X |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player O, choose row (0, 1, 2): 2 2
# Invalid input. Please enter integers between 0 and 2.
# Player O, choose row (0, 1, 2): 2
# Player O, choose column (0, 1, 2): 2
# X |   |
# ---------
#   |   |
# ---------
#   |   | O
# ---------
# Player X, choose row (0, 1, 2): 1
# Player X, choose column (0, 1, 2): 1
# X |   |
# ---------
#   | X |
# ---------
#   |   | O
# ---------
# Player O, choose row (0, 1, 2): 1
# Player O, choose column (0, 1, 2): 2
# X |   |
# ---------
#   | X | O
# ---------
#   |   | O
# ---------
# Player X, choose row (0, 1, 2): 0
# Player X, choose column (0, 1, 2): 1
# X | X |
# ---------
#   | X | O
# ---------
#   |   | O
# ---------
# Player O, choose row (0, 1, 2): 0
# Player O, choose column (0, 1, 2): 2
# X | X | O
# ---------
#   | X | O
# ---------
#   |   | O
# ---------
# Player O wins!
